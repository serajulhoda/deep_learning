# %% [markdown]
# <a href="https://colab.research.google.com/github/serajulhoda/deep_learning/blob/main/perceptron_trick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,5))
plt.scatter(X[:,0], X[:,1], c=y, cmap='plasma', s=100)

# %%
def step(z):
  return 1 if z>0 else 0

# %%
def perceptron(X, y):
  X = np.insert(X, 0, 1, axis=1)
  weights = np.ones(X.shape[1])
  lr = 0.1

  for i in range(1000):
    r = np.random.randint(1, X.shape[0])
    y_hat = step(np.dot(X[r], weights))
    weights = weights + lr*(y[r]-y_hat)*X[r]

  return weights[0], weights[1:]

# %%
intercept_, coef_ = perceptron(X,y)

# %%
print(coef_)
print(intercept_)
# Out:
# [1.32891596 0.0836092 ]
# 0.9

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3, 3, 100)
y_input = m*x_input + b

# %%
plt.figure(figsize=(11,5))
plt.plot(x_input, y_input, color='red', linewidth=3)
plt.scatter(X[:,0], X[:,1], c=y, cmap='plasma', s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
